# %%
import json


# function to load the data...

def load_name(filename):
    with open(filename, "r") as file :
        return json.load(file)

# function to find the pages that user might like...based on common interest...

def find_pages_you_might_like(user_id, data):
    
    # Dictionary to store user interaction with pages
    user_pages = {}

    # Populate the dictionary
    for user in data["users"]:
        user_pages[user["id"]] = set(user["liked_pages"])

    # if the user not found return empty list
    if user_id not in user_pages:
        return []

    user_liked_pages = user_pages[user_id]
    page_suggestion = {}
    
    
    for other_pages, pages in user_pages.items():
        if other_pages != user_id :
            shared_pages = user_liked_pages.intersection(pages)
        
            for page in pages:
                if page not in shared_pages:
                    page_suggestion[page] = page_suggestion.get(page, 0) + len(shared_pages)
                
    sorted_pages = sorted(page_suggestion.items(), key = lambda x : x[1], reverse = True)
    return [(page_id, score) for page_id, score in sorted_pages]


    # user liked pages...
    user_linked_pages = user_page[user_id]
    page_suggestion = {}
    


        
data = load_name("massive_data.json")
user_id = int(input("Enter the User ID for recommendation : "))
page_recomendation = find_pages_you_might_like(user_id, data)
print(page_recomendation)
# Out:
# Enter the User ID for recommendation :  5
# [(101, 1), (103, 1), (111, 1), (104, 0), (106, 0), (107, 0), (108, 0), (109, 0), (110, 0), (112, 0), (113, 0), (114, 0), (115, 0), (116, 0), (117, 0), (118, 0), (119, 0), (120, 0), (121, 0), (122, 0), (123, 0), (124, 0), (125, 0), (126, 0), (127, 0)]
